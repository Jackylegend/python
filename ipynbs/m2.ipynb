# %%
import pandas as pd 
import numpy as np
import pyecharts
import plotly.express as px # visualization
import pandas_datareader as pdr # access fred
from datetime import date
from fredapi import Fred
import requests
import openpyxl

from pyecharts.globals import CurrentConfig, NotebookType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_NOTEBOOK

from pyecharts import options as opts
from pyecharts.charts import Bar, Line

# %%
fred_key = 'a4459da91e23d9116f98724098d92428'
fred = Fred(api_key=fred_key)
today = date.today()


# Get Series Data
def get_fred_series_data(fred_key,series, **kwargs):
  # url
  url = "https://api.stlouisfed.org/fred/series/observations?series_id={}&api_key={}&file_type=json".format(series, fred_key)

  # response
  response = requests.get(url)
  data = response.json()
  return data


def get_fred_data(param_list, start_date, end_date):
  df = pdr.DataReader(param_list, 'fred', start_date, end_date)
  return df.reset_index()

# %%
data_code = pd.read_excel('C:/Users/fanjz/Desktop/python/m2/m2_code.xlsx')
code_monthly = data_code[data_code['Frequency'] == 'M']


code_monthly_list = code_monthly['Code'].tolist()

# %%
data_monthly = get_fred_data(param_list = code_monthly_list, start_date='1950-01-01', end_date=str(today))

data_monthly =  data_monthly.rename(columns={'DATE' : 'Date'})

# %%
data_monthly_df = data_monthly.melt(id_vars='Date', var_name='Code', value_name='Values')

# %%
data_monthly_merge = pd.merge(data_monthly_df, code_monthly, on='Code')

# %%
data_monthly_merge = data_monthly_merge.dropna(subset=['Values'])
data_monthly_merge['Date'] = data_monthly_merge['Date'].dt.strftime('%Y-%m-%d')

# %%
data_monthly_merge.to_excel('C:/Users/fanjz/Desktop/python/m2/m2.xlsx', index=False)

# %%
bar = Bar(init_opts=opts.InitOpts(theme=ThemeType.ROMANTIC))
bar.add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
bar.add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'romantic':'https://assets.pyecharts.org/assets/v5/themes/romantic'
#         }
#     });
# </script>
#
#         <div id="ab5e51d76fba435c997e454a2b3e89c9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'romantic'], function(echarts) {
#                 var chart_ab5e51d76fba435c997e454a2b3e89c9 = echarts.init(
#                     document.getElementById('ab5e51d76fba435c997e454a2b3e89c9'), 'romantic', {renderer: 'canvas'});
#                 var option_ab5e51d76fba435c997e454a2b3e89c9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
# ...
